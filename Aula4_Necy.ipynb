# %%
def erroab (x,y,eaX,eaY):    #absoluto
   eaxy=eaX+erY


def erro relativo (x,y,erX,erY):#relativo
 erX(x/x+y)+erY(y/x+y)

# %%
import matplotlib.pyplot as plt
import numpy as np

def funcao(t):
    return 10**(1-t)
def funcao1(t):
    return 10**(1-t)*1/2

n = np.linspace(2,12, num=1000)
plt.plot(n, funcao(n))
plt.plot(n, funcao1(n), color="red")
plt.show()

# %%
ER=0.1/2112.9
print(ER)
ER
# Out:
# 4.732831653178097e-05
# 4.732831653178097e-05
